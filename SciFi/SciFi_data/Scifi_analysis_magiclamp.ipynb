# %%
from google.colab import drive
drive.mount('/content/drive/Dortmund_SciFi')

# %%
import pickle

file = "SimData.pkl"

# Open the file in binary read mode and load its contents
with open(file, 'rb') as f:
    data = pickle.load(f)S

# Print or inspect the loaded data
print(type(data))
print(data)
